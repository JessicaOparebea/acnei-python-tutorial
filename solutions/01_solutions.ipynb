# %% [markdown]
# # Solutions — 01: Setup & First Steps
#
# **ACNEI Computational Neuroscience Introductory School | May 2026**
#
# ---

# %% [markdown]
# ### Exercise 1 — Print your name and university

# %%
print("Jessica Oparebea")
print("University of Ghana")

# %% [markdown]
# ### Exercise 2 — Print 1 through 5 separated by ` → ` in a single print() call

# %%
print(1, 2, 3, 4, 5, sep=" → ")

# %% [markdown]
# ### Exercise 3 — What does print() with no arguments do?

# %%
print()  # Prints a blank line (just a newline character).
         # Useful for adding vertical spacing between lines of output.

# %% [markdown]
# ### Exercise 4 — Multi-line comment block about learning goals

# %%
# I hope to learn how to:
# - Analyse neural spike trains with Python
# - Build and visualise computational neuron models
# - Use NumPy and Matplotlib for scientific data analysis
# - Apply statistical tests to experimental neuroscience data

# %% [markdown]
# ---
# ➡️ Next: [02 — Variables & Data Types Solutions](02_solutions.ipynb)
